# %% [markdown]
# <a href="https://colab.research.google.com/github/ashkanvg/jsonpath_validator_python/blob/main/query_validator.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Imports

# %%
# !pip -q install jmespath jsonpath-ng
# !pip -q install jsonpath-ng
# !pip install "jsonpath-ng[ext]"
# !pip install jsonpath2
# Out:
# Requirement already satisfied: jsonpath2 in /usr/local/lib/python3.12/dist-packages (0.4.5)
# Requirement already satisfied: antlr4-python3-runtime==4.10 in /usr/local/lib/python3.12/dist-packages (from jsonpath2) (4.10)

# %%
# pip install jsonpath2
import json, random, sys
from jsonpath2.path import Path

# %%
# --- Load data ---
# wrap into an array
def load_json_or_jsonl(path):
    with open(path, "r", encoding="utf-8") as f:
        first = f.read(1)
        f.seek(0)
        if first == '[':
            return json.load(f)
        # NDJSON fallback
        return [json.loads(line) for line in f if line.strip()]

def run(expr, dataset):
    path = Path.parse_str(expr)
    matches = [m.current_value for m in path.match(dataset)]
    print(f"\n{expr}\n→ {len(matches)} match(es)")
    # preview up to 5 results (avoid dumping big arrays)
    for v in matches[:5]:
        print("  ", v)

# %%
# Example: works for either .json (object/array) or .jsonl (JSON Lines) files
json_path = "./github_archive_sample_25.json"

data = load_json_or_jsonl(json_path)  # or "events.jsonl"
assert isinstance(data, list), "Expected a top-level array"
print(f"Loaded {len(data)} records")
# Out:
# Loaded 25 records

# %%
# --- Queries (from above) ---
queries = [
    '$[*].id',
    '$[*].type',
    '$[*].public',
    '$[*].created_at',
    '$[*].actor.login',
    '$[*].actor.url',
    '$[*].repo.name',
    '$[*].repo.url',
    '$[*].payload.action',
    '$[*].payload.comment.id',
    '$[*].payload.comment.path',
    '$[*].payload.comment.user.login',
    '$[*].payload.comment._links.self.href',
    '$[*].payload.pull_request.id',
    '$[*].payload.pull_request.title',
    '$[*].payload.pull_request.state',
    '$[*].payload.pull_request.user.login',
    '$[*].payload.pull_request.assignee.login',
    '$[*].payload.pull_request.head.ref',
    '$[*].payload.pull_request.head.repo.full_name',
    '$[*].payload.pull_request.head.repo.language',
    '$[*].payload.pull_request.base.ref',
    '$[*].payload.pull_request._links.statuses.href',
    '$[*].org.login',
    '$[0].id',
    '$[17].actor.login',
    '$[42].payload.pull_request.title',
    '$[42].payload.pull_request._links.statuses.href',
    '$[99].payload.comment.user.login',
    '$[123].payload.pull_request.head.repo.full_name',
    '$[512].repo.url',
    '$[777].org.login',
    '$[123].payload.pull_request["html_url","diff_url","patch_url"]',
    '$[256]..created_at',
    '$[*]..created_at',
    '$[*]..id',
    '$[*]..url',
    '$[*].payload.pull_request["html_url","diff_url","patch_url"]',
    '$[*].payload.pull_request._links.*.href',
    '$[*].payload.*.id',

    '$[*][?(@.payload.pull_request.state = "open")].payload.pull_request["id","number","title"]',
    '$[*].payload.pull_request["head","base"]["ref","sha"]',
    '$[*].payload.pull_request["head","base"][?(@.repo.language = "Go")].repo["full_name","watchers_count"]',
    '$[*].payload.pull_request._links.*.href',
    '$[*].payload.pull_request._links["self","review_comments","commits"].href',
    '$[*].payload.pull_request._links["comments","review_comments"].href',
    '$[*][?(@.actor.login = "azylman" or @.payload.comment.user.id = 790102)].id',
    '$[*]..login',
    '$[*].payload.pull_request..["created_at","updated_at","closed_at","merged_at"]',
    '$[*][?(@.payload.comment.path = "Makefile" and @.payload.comment.position = 9)].payload.comment["path","position","diff_hunk"]',
    '$[*].payload.pull_request["head","base"].repo["git_url","ssh_url","clone_url"]',
    '$[*]..["stargazers_count","forks_count","open_issues_count"]',
    '$[*].payload.pull_request["head","base"].user.login',
    '$[*]..["issue_url","comments_url","review_comments_url","commits_url","statuses_url"]',
    '$[*].payload.pull_request.head.repo["full_name","default_branch"]',
    '$[*].payload.pull_request.base.repo["full_name","default_branch"]',
    '$[0:5].id',
    '$[::5].id',
    '$[-1].id',
    '$[*][?(@.org and @.org.login = "Clever")].org["login","id"]',
    '$[*]..id',
    '$[*]..url',
    '$[*].payload.pull_request["head","base"][?(@.label = "Clever:add-support-for-more-delimiters" or @.label = "Clever:master")]["label","ref"]',
    '$[*][?(@.payload.pull_request.user.login and @.payload.pull_request.assignee.login and @.payload.pull_request.user.login != @.payload.pull_request.assignee.login)].payload.pull_request["user","assignee"].login',
    '$[*].payload.pull_request["head","base"][0:1].ref',
    '$[*].payload.pull_request["head","base"][-1:].ref',
    '$[*].payload.pull_request["head","base"][?(@.repo.open_issues_count > 0)].repo.open_issues_count',
    '$[*][?(@.payload.comment)].payload.comment.user["login","html_url"]',
    '$[*].payload.pull_request._links.*["href"][length()]',
    '$[*].payload.comment.diff_hunk[substring(0, 40)]',
]

# %%
for q in queries:
    # print(q)
    # print("\n")
    run(q, data)
# Out:
# $[*].id
# → 25 match(es)
#    2491008872
#    2491008873
#    2491008875
#    2491008880
#    2491008889
#
# $[*].type
# → 25 match(es)
#    CreateEvent
#    PullRequestEvent
#    IssuesEvent
#    WatchEvent
#    ForkEvent
#
# $[*].public
# → 25 match(es)
#    True
#    True
#    True
#    True
#    True
#
# $[*].created_at
# → 25 match(es)
#    2015-01-02T23:00:00Z
#    2015-01-02T23:00:00Z
#    2015-01-02T23:00:00Z
#    2015-01-02T23:00:00Z
#    2015-01-02T23:00:01Z
#
# $[*].actor.login
# → 25 match(es)
#    unwarysheep
#    erwinvanhunen
#    alpha-beta-soup
#    finbarr
#    agung-wete
#
# $[*].actor.url
# → 25 match(es)
#    https://api.github.com/users/unwarysheep
#    https://api.github.com/users/erwinvanhunen
#    https://api.github.com/users/alpha-beta-soup
#    https://api.github.com/users/finbarr
#    https://api.github.com/users/agung-wete
#
# $[*].repo.name
# → 25 match(es)
#    unwarysheep/blog
#    OfficeDev/PnP
#    alpha-beta-soup/national-crash-statistics
#    motdotla/dotenv
#    gwarnants/FunctionList-PHP-Patch
#
# $[*].repo.url
# → 25 match(es)
#    https://api.github.com/repos/unwarysheep/blog
#    https://api.github.com/repos/OfficeDev/PnP
#    https://api.github.com/repos/alpha-beta-soup/national-crash-statistics
#    https://api.github.com/repos/motdotla/dotenv
#    https://api.github.com/repos/gwarnants/FunctionList-PHP-Patch
#
# $[*].payload.action
# → 11 match(es)
#    opened
#    opened
#    started
#    closed
#    created
#
# $[*].payload.comment.id
# → 3 match(es)
#    68571051
#    68571054
#    22426089
#
# $[*].payload.comment.path
# → 1 match(es)
#    Makefile
#
# $[*].payload.comment.user.login
# → 3 match(es)
#    marineam
#    anodelman
#    azylman
#
# $[*].payload.comment._links.self.href
# → 1 match(es)
#    https://api.github.com/repos/Clever/csvlint/pulls/comments/22426089
#
# $[*].payload.pull_request.id
# → 2 match(es)
#    26774680
#    26765858
#
# $[*].payload.pull_request.title
# → 2 match(es)
#    Group and context
#    Add support for more delimiters
#
# $[*].payload.pull_request.state
# → 2 match(es)
#    open
#    open
#
# $[*].payload.pull_request.user.login
# → 2 match(es)
#    erwinvanhunen
#    schimmy
#
# $[*].payload.pull_request.assignee.login
# → 1 match(es)
#    azylman
#
# $[*].payload.pull_request.head.ref
# → 2 match(es)
#    GroupAndContext
#    add-support-for-more-delimiters
#
# $[*].payload.pull_request.head.repo.full_name
# → 2 match(es)
#    erwinvanhunen/PnP
#    Clever/csvlint
#
# $[*].payload.pull_request.head.repo.language
# → 2 match(es)
#    C#
#    Go
#
# $[*].payload.pull_request.base.ref
# → 2 match(es)
#    dev
#    master
#
# $[*].payload.pull_request._links.statuses.href
# → 2 match(es)
#    https://api.github.com/repos/OfficeDev/PnP/statuses/582e579d4b78474121ae23eb9bfcbb78df4f125b
#    https://api.github.com/repos/Clever/csvlint/statuses/f6d3fb52bf68e4070b424584384157856a57a3da
#
# $[*].org.login
# → 10 match(es)
#    OfficeDev
#    coreos
#    coreos
#    github
#    puppetlabs
#
# $[0].id
# → 1 match(es)
#    2491008872
#
# $[17].actor.login
# → 1 match(es)
#    zoic21
#
# $[42].payload.pull_request.title
# → 0 match(es)
#
# $[42].payload.pull_request._links.statuses.href
# → 0 match(es)
#
# $[99].payload.comment.user.login
# → 0 match(es)
#
# $[123].payload.pull_request.head.repo.full_name
# → 0 match(es)
#
# $[512].repo.url
# → 0 match(es)
#
# $[777].org.login
# → 0 match(es)
#
# $[123].payload.pull_request["html_url","diff_url","patch_url"]
# → 0 match(es)
#
# $[256]..created_at
# → 0 match(es)
#
# $[*]..created_at
# → 40 match(es)
#    2015-01-02T23:00:00Z
#    2015-01-02T23:00:00Z
#    2015-01-02T22:59:59Z
#    2014-08-18T23:09:31Z
#    2014-07-27T02:08:15Z
#
# $[*]..id
# → 120 match(es)
#    2491008872
#    493834
#    28728953
#    2491008873
#    7666381
#
# $[*]..url
# → 108 match(es)
#    https://api.github.com/users/unwarysheep
#    https://api.github.com/repos/unwarysheep/blog
#    https://api.github.com/users/erwinvanhunen
#    https://api.github.com/repos/OfficeDev/PnP
#    https://api.github.com/repos/OfficeDev/PnP/pulls/348
#
# $[*].payload.pull_request["html_url","diff_url","patch_url"]
# → 6 match(es)
#    https://github.com/OfficeDev/PnP/pull/348
#    https://github.com/OfficeDev/PnP/pull/348.diff
#    https://github.com/OfficeDev/PnP/pull/348.patch
#    https://github.com/Clever/csvlint/pull/5
#    https://github.com/Clever/csvlint/pull/5.diff
#
# $[*].payload.pull_request._links.*.href
# → 16 match(es)
#    https://api.github.com/repos/OfficeDev/PnP/pulls/348
#    https://github.com/OfficeDev/PnP/pull/348
#    https://api.github.com/repos/OfficeDev/PnP/issues/348
#    https://api.github.com/repos/OfficeDev/PnP/issues/348/comments
#    https://api.github.com/repos/OfficeDev/PnP/pulls/348/comments
#
# $[*].payload.*.id
# → 11 match(es)
#    26774680
#    53284300
#    28728956
#    53221568
#    53221568
#
# $[*][?(@.payload.pull_request.state = "open")].payload.pull_request["id","number","title"]
# → 6 match(es)
#    26774680
#    348
#    Group and context
#    26765858
#    5
#
# $[*].payload.pull_request["head","base"]["ref","sha"]
# → 8 match(es)
#    GroupAndContext
#    582e579d4b78474121ae23eb9bfcbb78df4f125b
#    dev
#    cc6cb4f469fae41788275d84da04f796b73e2e67
#    add-support-for-more-delimiters
#
# $[*].payload.pull_request["head","base"][?(@.repo.language = "Go")].repo["full_name","watchers_count"]
# → 4 match(es)
#    Clever/csvlint
#    3
#    Clever/csvlint
#    3
#
# $[*].payload.pull_request._links.*.href
# → 16 match(es)
#    https://api.github.com/repos/OfficeDev/PnP/pulls/348
#    https://github.com/OfficeDev/PnP/pull/348
#    https://api.github.com/repos/OfficeDev/PnP/issues/348
#    https://api.github.com/repos/OfficeDev/PnP/issues/348/comments
#    https://api.github.com/repos/OfficeDev/PnP/pulls/348/comments
#
# $[*].payload.pull_request._links["self","review_comments","commits"].href
# → 6 match(es)
#    https://api.github.com/repos/OfficeDev/PnP/pulls/348
#    https://api.github.com/repos/OfficeDev/PnP/pulls/348/comments
#    https://api.github.com/repos/OfficeDev/PnP/pulls/348/commits
#    https://api.github.com/repos/Clever/csvlint/pulls/5
#    https://api.github.com/repos/Clever/csvlint/pulls/5/comments
#
# $[*].payload.pull_request._links["comments","review_comments"].href
# → 4 match(es)
#    https://api.github.com/repos/OfficeDev/PnP/issues/348/comments
#    https://api.github.com/repos/OfficeDev/PnP/pulls/348/comments
#    https://api.github.com/repos/Clever/csvlint/issues/5/comments
#    https://api.github.com/repos/Clever/csvlint/pulls/5/comments
#
# $[*][?(@.actor.login = "azylman" or @.payload.comment.user.id = 790102)].id
# → 1 match(es)
#    2491008955
#
# $[*]..login
# → 55 match(es)
#    unwarysheep
#    erwinvanhunen
#    erwinvanhunen
#    erwinvanhunen
#    erwinvanhunen
#
# $[*].payload.pull_request..["created_at","updated_at","closed_at","merged_at"]
# → 16 match(es)
#    2015-01-02T22:59:59Z
#    2015-01-02T22:59:59Z
#    None
#    None
#    2014-08-18T23:09:31Z
#
# $[*][?(@.payload.comment.path = "Makefile" and @.payload.comment.position = 9)].payload.comment["path","position","diff_hunk"]
# → 3 match(es)
#    Makefile
#    9
#    @@ -28,10 +28,9 @@ endif
#  ifeq ($(COVERAGE),1)
#  	@go test -cover -coverprofile=$(GOPATH)/src/$@/c.out $@ -test.v
#  	@go tool cover -html=$(GOPATH)/src/$@/c.out
# -else
# -	@echo "TESTING..."
# -	@go test $@ -test.v
#  endif
# +	@echo "TESTING... $@"
# +	@go test $@ -test.v
#
# $[*].payload.pull_request["head","base"].repo["git_url","ssh_url","clone_url"]
# → 12 match(es)
#    git://github.com/erwinvanhunen/PnP.git
#    git@github.com:erwinvanhunen/PnP.git
#    https://github.com/erwinvanhunen/PnP.git
#    git://github.com/OfficeDev/PnP.git
#    git@github.com:OfficeDev/PnP.git
#
# $[*]..["stargazers_count","forks_count","open_issues_count"]
# → 18 match(es)
#    1
#    0
#    0
#    202
#    209
#
# $[*].payload.pull_request["head","base"].user.login
# → 4 match(es)
#    erwinvanhunen
#    OfficeDev
#    Clever
#    Clever
#
# $[*]..["issue_url","comments_url","review_comments_url","commits_url","statuses_url"]
# → 34 match(es)
#    https://api.github.com/repos/OfficeDev/PnP/issues/348
#    https://api.github.com/repos/OfficeDev/PnP/issues/348/comments
#    https://api.github.com/repos/OfficeDev/PnP/pulls/348/comments
#    https://api.github.com/repos/OfficeDev/PnP/pulls/348/commits
#    https://api.github.com/repos/OfficeDev/PnP/statuses/582e579d4b78474121ae23eb9bfcbb78df4f125b
#
# $[*].payload.pull_request.head.repo["full_name","default_branch"]
# → 4 match(es)
#    erwinvanhunen/PnP
#    dev
#    Clever/csvlint
#    master
#
# $[*].payload.pull_request.base.repo["full_name","default_branch"]
# → 4 match(es)
#    OfficeDev/PnP
#    master
#    Clever/csvlint
#    master
#
# $[0:5].id
# → 5 match(es)
#    2491008872
#    2491008873
#    2491008875
#    2491008880
#    2491008889
#
# $[::5].id
# → 5 match(es)
#    2491008872
#    2491008892
#    2491008923
#    2491008944
#    2491008954
#
# $[-1].id
# → 1 match(es)
#    2491008967
#
# $[*][?(@.org and @.org.login = "Clever")].org["login","id"]
# → 2 match(es)
#    Clever
#    1885509
#
# $[*]..id
# → 120 match(es)
#    2491008872
#    493834
#    28728953
#    2491008873
#    7666381
#
# $[*]..url
# → 108 match(es)
#    https://api.github.com/users/unwarysheep
#    https://api.github.com/repos/unwarysheep/blog
#    https://api.github.com/users/erwinvanhunen
#    https://api.github.com/repos/OfficeDev/PnP
#    https://api.github.com/repos/OfficeDev/PnP/pulls/348
#
# $[*].payload.pull_request["head","base"][?(@.label = "Clever:add-support-for-more-delimiters" or @.label = "Clever:master")]["label","ref"]
# → 4 match(es)
#    Clever:add-support-for-more-delimiters
#    add-support-for-more-delimiters
#    Clever:master
#    master
#
# $[*][?(@.payload.pull_request.user.login and @.payload.pull_request.assignee.login and @.payload.pull_request.user.login != @.payload.pull_request.assignee.login)].payload.pull_request["user","assignee"].login
# → 2 match(es)
#    schimmy
#    azylman
#
# $[*].payload.pull_request["head","base"][0:1].ref
# → 0 match(es)
#
# $[*].payload.pull_request["head","base"][-1:].ref
# → 0 match(es)
#
# $[*].payload.pull_request["head","base"][?(@.repo.open_issues_count > 0)].repo.open_issues_count
# → 3 match(es)
#    25
#    4
#    4
#
# $[*][?(@.payload.comment)].payload.comment.user["login","html_url"]
# → 6 match(es)
#    marineam
#    https://github.com/marineam
#    anodelman
#    https://github.com/anodelman
#    azylman
#
# $[*].payload.pull_request._links.*["href"][length()]
# → 16 match(es)
#    52
#    41
#    53
#    62
#    61
#
# $[*].payload.comment.diff_hunk[substring(0, 40)]
# → 1 match(es)
#    @@ -28,10 +28,9 @@ endif
#  ifeq ($(COVERA
